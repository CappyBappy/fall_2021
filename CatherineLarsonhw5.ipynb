# %% [markdown]
# ## Instructions ##
# - Run the first code cell with the imports below, then run the cell below it
# - Follow the on-screen prompts to play.

# %%
from IPython.display import clear_output
import time
import random

# %%
water = "🌊"
waterfield = water*20+'\n'+water*20+'\n'+water*20+'\n'+water*20+'\n'+water*20+'\n'+water*20
# new lines arte at indices 20, 41, 62, 83, and 104
# each line has 21
print("Welcome to the ocean! You live in a peaceful ocean neighborhood, with fish and creatures everywhere.")
fieldlist = list(waterfield)
fieldlist[16] = '🦈'
fieldlist[8] = '🐠'
fieldlist[2] = '🐳'
fieldlist[32] = '🐬'
fieldlist[18] = '🐠'
fieldlist[45] = '🦈'
fieldlist[78] = '🐠'
fieldlist[54] = '🦈'
fieldlist[93] = '🐬'
fieldlist[120] = '🐳'
fieldlist[110] = '🐠'
happyfield = fieldlist
print(''.join(happyfield))
time.sleep(5)
clear_output(wait=True)
fieldlist = list(waterfield)
fieldlist[23] = '🐲'
fieldlist[38] = '🐲'
fieldlist[86] = '🐲'
fieldlist[101] = '🐲'
d1=23
d2=38
d3=86
d4=101
bhp = 120
battack = 6
bdefense = 7
baccuracy = 9
d1alive = True
d2alive = True
d3alive = True
d4alive = True
bossAlive = True
print(''.join(fieldlist))
print("Oh no! Your home has been invaded by monsters! Looks like you'll have to fight them off if you want your friends to come back.")
character = '🐠'
hp = 100
gameRunning = True
playerWon = False
playerPos = 52
time.sleep(1)
emptySpaces = [20, 41, 62, 83, 104]
fieldlist[playerPos] = character
print(''.join(fieldlist))
clear_output(wait=True)
while(gameRunning):
    attack = 7
    defense = 5
    accuracy = 5
    dhp = 30
    dattack = 3
    ddefense = 3
    daccuracy = 3
    move = input('Enter "w" to move up, "a" to move left, "s" to move down, and "d" to move right. Enter "quit" to quit the game.')
    if move == 'a':
        if((playerPos-1)!=20 and (playerPos-1)!=41 and (playerPos-1)!=62 and (playerPos-1)!=83 and (playerPos-1)!=104):
            fieldlist[playerPos] = water
            playerPos = playerPos-1
            fieldlist[playerPos] = character
    elif move == 'd':
        if((playerPos+1)!=20 and (playerPos+1)!=41 and (playerPos+1)!=62 and (playerPos+1)!=83 and (playerPos+1)!=104):
            fieldlist[playerPos] = water
            playerPos = playerPos+1
            fieldlist[playerPos] = character
    elif move == 'w':
        if(playerPos-21 >= 0):
            fieldlist[playerPos] = water
            playerPos = playerPos-21
            fieldlist[playerPos] = character
    elif move == 's':
        if(playerPos+21 < len(fieldlist)):
            fieldlist[playerPos] = water
            playerPos = playerPos+21
            fieldlist[playerPos] = character
    elif move == 'quit' or move == 'Quit':
        print('Game over. Thanks for playing!')
        break
    if(playerPos == d1 and d1alive):
        print("You've run into one of the monsters!")
        while(d1alive):
            print('🐲 🐠')
            print("HP: "+ str(hp))
            print("Monster HP: " + str(dhp))
            print("What will you do?")
            print("1. Attack.")
            print("2. Raise Stats.")
            print("3. Heal up.")
            battleChoice = input("Please enter your choice in integer form: ")
            if(battleChoice == '1'):
                hit = random.randint(1, 7)
                if(hit <= accuracy):
                    damagemult = random.randint(1,3)
                    damage = (attack*damagemult)-ddefense
                    if(damage<0):
                        damage = 0
                    dhp = dhp - damage
                    print("You did", damage, "damage to the monster!")
                    if(dhp <= 0):
                        d1alive = False
                        print("Congrats, you've beaten the monster!")
                        break
                else:
                    print("You missed.")
            elif(battleChoice == '2'):
                attack = random.randint(1,2) + attack
                defense = random.randint(1,2) + defense
                accuracy = random.randint(1,2) + accuracy
                print("Stats have been risen.")
            elif(battleChoice == '3'):
                hp = hp + random.randint(5, 10)
                if(hp > 100):
                    hp = 100
                print("Healed up. Health is currently", hp)
            dChoice = random.randint(1,2)
            if(dChoice == 1):
                hit = random.randint(1, 7)
                if(hit <= daccuracy):
                    damagemult = random.randint(1,3)
                    damage = (dattack*damagemult)-defense
                    if(damage<0):
                        damage = 0
                    hp = hp - damage
                    print("The monster did", damage, "damage to you!")
                    if(hp <= 0):
                        gameRunning = False
                        print("The monster beat you, game over.")
                        break
            elif(dChoice == 2):
                dattack = random.randint(1,2) + dattack
                ddefense = random.randint(1,2) + ddefense
                daccuracy = random.randint(1,2) + daccuracy
                print("The monster raised its stats.")
            time.sleep(2)
            clear_output(wait=False)
    elif(playerPos == d2 and d2alive):
        print("You've run into one of the monsters!")
        while(d2alive):
            print('🐲 🐠')
            print("HP: "+ str(hp))
            print("Monster HP: " + str(dhp))
            print("What will you do?")
            print("1. Attack.")
            print("2. Raise Stats.")
            print("3. Heal up.")
            battleChoice = input("Please enter your choice in integer form: ")
            if(battleChoice == '1'):
                hit = random.randint(1, 7)
                if(hit <= accuracy):
                    damagemult = random.randint(1,2)
                    damage = (attack*damagemult)-ddefense
                    if(damage<0):
                        damage = 0
                    dhp = dhp - damage
                    print("You did", damage, "damage to the monster!")
                    if(dhp <= 0):
                        d2alive = False
                        print("Congrats, you've beaten the monster!")
                        break
                else:
                    print("You missed.")
            elif(battleChoice == '2'):
                attack = random.randint(1,2) + attack
                defense = random.randint(1,2) + defense
                accuracy = random.randint(1,2) + accuracy
                print("Stats have been risen.")
            elif(battleChoice == '3'):
                hp = hp + random.randint(5, 10)
                if(hp > 100):
                    hp = 100
                print("Healed up. Health is currently", hp)
            dChoice = random.randint(1,2)
            if(dChoice == 1):
                hit = random.randint(1, 7)
                if(hit <= daccuracy):
                    damagemult = random.randint(1,2)
                    damage = (dattack*damagemult)-defense
                    if(damage<0):
                        damage = 0
                    hp = hp - damage
                    print("The monster did", damage, "damage to you!")
                    if(hp <= 0):
                        gameRunning = False
                        print("The monster beat you, game over.")
                        break
            elif(dChoice == 2):
                dattack = random.randint(1,2) + dattack
                ddefense = random.randint(1,2) + ddefense
                daccuracy = random.randint(1,2) + daccuracy
                print("The monster raised its stats.")
            time.sleep(2)
            clear_output(wait=False)
    elif(playerPos == d3 and d3alive):
        print("You've run into one of the monsters!")
        while(d3alive):
            print('🐲 🐠')
            print("HP: "+ str(hp))
            print("Monster HP: " + str(dhp))
            print("What will you do?")
            print("1. Attack.")
            print("2. Raise Stats.")
            print("3. Heal up.")
            battleChoice = input("Please enter your choice in integer form: ")
            if(battleChoice == '1'):
                hit = random.randint(1, 7)
                if(hit <= accuracy):
                    damagemult = random.randint(1,2)
                    damage = (attack*damagemult)-ddefense
                    if(damage<0):
                        damage = 0
                    dhp = dhp - damage
                    print("You did", damage, "damage to the monster!")
                    if(dhp <= 0):
                        d3alive = False
                        print("Congrats, you've beaten the monster!")
                        break
                else:
                    print("You missed.")
            elif(battleChoice == '2'):
                attack = random.randint(1,2) + attack
                defense = random.randint(1,2) + defense
                accuracy = random.randint(1,2) + accuracy
                print("Stats have been risen.")
            elif(battleChoice == '3'):
                hp = hp + random.randint(5, 10)
                if(hp > 100):
                    hp = 100
                print("Healed up. Health is currently", hp)
            dChoice = random.randint(1,2)
            if(dChoice == 1):
                hit = random.randint(1, 7)
                if(hit <= daccuracy):
                    damagemult = random.randint(1,2)
                    damage = (dattack*damagemult)-defense
                    if(damage<0):
                        damage = 0
                    hp = hp - damage
                    print("The monster did", damage, "damage to you!")
                    if(hp <= 0):
                        gameRunning = False
                        print("The monster beat you, game over.")
                        break
            elif(dChoice == 2):
                dattack = random.randint(1,2) + dattack
                ddefense = random.randint(1,2) + ddefense
                daccuracy = random.randint(1,2) + daccuracy
                print("The monster raised its stats.")
            time.sleep(2)
            clear_output(wait=False)
    elif(playerPos == d4 and d4alive):
        print("You've run into one of the monsters!")
        while(d4alive):
            print('🐲 🐠')
            print("HP: "+ str(hp))
            print("Monster HP: " + str(dhp))
            print("What will you do?")
            print("1. Attack.")
            print("2. Raise Stats.")
            print("3. Heal up.")
            battleChoice = input("Please enter your choice in integer form: ")
            if(battleChoice == '1'):
                hit = random.randint(1, 7)
                if(hit <= accuracy):
                    damagemult = random.randint(1,2)
                    damage = (attack*damagemult)-ddefense
                    if(damage<0):
                        damage = 0
                    dhp = dhp - damage
                    print("You did", damage, "damage to the monster!")
                    if(dhp <= 0):
                        d4alive = False
                        print("Congrats, you've beaten the monster!")
                        break
                else:
                    print("You missed.")
            elif(battleChoice == '2'):
                attack = random.randint(1,2) + attack
                defense = random.randint(1,2) + defense
                accuracy = random.randint(1,2) + accuracy
                print("Stats have been risen.")
            elif(battleChoice == '3'):
                hp = hp + random.randint(5, 10)
                if(hp > 100):
                    hp = 100
                print("Healed up. Health is currently", hp)
            dChoice = random.randint(1,2)
            if(dChoice == 1):
                hit = random.randint(1, 7)
                if(hit <= daccuracy):
                    damagemult = random.randint(1,2)
                    damage = (dattack*damagemult)-defense
                    if(damage<0):
                        damage = 0
                    hp = hp - damage
                    print("The monster did", damage, "damage to you!")
                    if(hp <= 0):
                        gameRunning = False
                        print("The monster beat you, game over.")
                        break
            elif(dChoice == 2):
                dattack = random.randint(1,2) + dattack
                ddefense = random.randint(1,2) + ddefense
                daccuracy = random.randint(1,2) + daccuracy
                print("The monster raised its stats.")
            time.sleep(2)
            clear_output(wait=False)
    if(not (d1alive or d2alive or d3alive or d4alive)):
        playerWon = True
        gameRunning = False
        break
    if(gameRunning):
        print(''.join(fieldlist))
        clear_output(wait=True)
if(playerWon):
    print(''.join(fieldlist))
    print("You hear a rumbling sound beneath you.")
    time.sleep(3)
    clear_output(wait=True)
    fieldlist[52] = '🦖'
    print(''.join(fieldlist))
    print("It's the leader of the monsters!")
    time.sleep(3)
    clear_output(wait=False)
    while(bossAlive):
        print('🦖 🐠')
        print("HP: "+ str(hp))
        print("Boss HP: " + str(bhp))
        print("What will you do?")
        print("1. Attack.")
        print("2. Raise Stats.")
        print("3. Heal up.")
        battleChoice = input("Please enter your choice in integer form: ")
        if(battleChoice == '1'):
            hit = random.randint(1, 7)
            if(hit <= accuracy):
                damagemult = random.randint(1,3)
                damage = (attack*damagemult)-bdefense
                if(damage<0):
                    damage = 0
                bhp = bhp - damage
                print("You did", damage, "damage to the boss!")
                if(bhp <= 0):
                    bossAlive = False
                    break
            else:
                print("You missed.")
                time.sleep('2')
        elif(battleChoice == '2'):
            attack = random.randint(1,2) + attack
            defense = random.randint(1,2) + defense
            accuracy = random.randint(1,2) + accuracy
            print("Stats have been risen.")
        elif(battleChoice == '3'):
            hp = hp + random.randint(5, 10)
            if(hp > 100):
                hp = 100
            print("Healed up. Health is currently", hp)
        bChoice = random.randint(1,2)
        if(bChoice == 1):
            hit = random.randint(1, 7)
            if(hit <= baccuracy):
                damagemult = random.randint(1,3)
                damage = (battack*damagemult)-defense
                if(damage<0):
                    damage = 0
                hp = hp - damage
                print("The boss did", damage, "damage to you!")
                if(hp <= 0):
                    print("The boss beat you, game over.")
                    break
        elif(bChoice == 2):
            battack = random.randint(1,2) + battack
            bdefense = random.randint(1,2) + bdefense
            baccuracy = random.randint(1,2) + baccuracy
            print("The boss raised its stats.")
        time.sleep(2)
        clear_output(wait=False)
if(not bossAlive):
    print(''.join(happyfield))
    print("Congrats! The monsters have left and peace has returned to the ocean.")
# Out:
# 🦖 🐠
# HP: 41
# Boss HP: 31
# What will you do?
# 1. Attack.
# 2. Raise Stats.
# 3. Heal up.
# Please enter your choice in integer form: 1
# You did 22 damage to the boss!
# The boss did 56 damage to you!
# The boss beat you, game over.
